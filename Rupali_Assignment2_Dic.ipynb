# %% [markdown]
# # Basic Dictionay Operations

# %% [markdown]
# 1. Create a dictionary with 3 key-value pairs (name, age, city).

# %%
info = {"name":"Robb", "age":24, "city":"Texas"}
info
# Out:
# {'name': 'Robb', 'age': 24, 'city': 'Texas'}

# %% [markdown]
# 2. Create a dictionary and print the value of a specific key.

# %%
info = {"name":"Robb", "age":24, "city":"Texas"}

print(info["name"])
# Out:
# Robb

# %% [markdown]
# 3. Make a dictionary and add a new key-value pair to it.

# %%
info = {"name":"Robb", "age":24, "city":"Texas"}

info["country"] = "USA"

info
# Out:
# {'name': 'Robb', 'age': 24, 'city': 'Texas', 'country': 'USA'}

# %% [markdown]
# 4. Create a dictionary and change the value of an existing key.

# %%
info = {"name":"Robb", "age":24, "city":"Texas"}

info["city"] = "New York"
info
# Out:
# {'name': 'Robb', 'age': 24, 'city': 'New York'}

# %% [markdown]
# 5. Create a dictionary and remove one key using pop().

# %%
input = {"id":5, "name":"john", "department":"Devops"}

print(input.pop("id"))
input
# Out:
# 5
# {'name': 'john', 'department': 'Devops'}

# %% [markdown]
# 6. Create a dictionary and remove the last inserted item using popitem().

# %%
info = {"name":"Robb", "age":24, "city":"Texas"}

print(info.popitem())
info
# Out:
# ('city', 'Texas')
# {'name': 'Robb', 'age': 24}

# %% [markdown]
# 7. Create a dictionary and print all the keys.

# %%
details = {"model": 123, "Company":"abc", "Price":20000}

details.keys()
# Out:
# dict_keys(['model', 'Company', 'Price'])

# %% [markdown]
# 8. Create a dictionary and print all the values.

# %%
details = {"model": 123, "Company":"abc", "Price":20000}

details.values()
# Out:
# dict_values([123, 'abc', 20000])

# %% [markdown]
# 9. Create a dictionary and print all the key-value items.

# %%
details = {"model": 123, "Company":"abc", "Price":20000}

# %% [markdown]
# 10. Make a dictionary and check the number of items using len().

# %%
details = {"model": 123, "Company":"abc", "Price":20000}

len(details)
# Out:
# 3

# %% [markdown]
# 11. Create a dictionary and check if a certain key exists (using "key" in dict).

# %%
input = {"id":5, "name":"john", "department":"Devops"}
print("name" in input)
print("city" in input)
# Out:
# True
# False

# %% [markdown]
# 12. Create an empty dictionary and add two key-value pairs one by one.

# %%
text = {}
text["sub"] = "English"
print(text)

text["marks"] = 90
print(text)
# Out:
# {'sub': 'English'}
# {'sub': 'English', 'marks': 90}

# %% [markdown]
# 13. Create a dictionary and update one key’s value using update().

# %%
set = {"id":5, "name":"john", "department":"Devops"}

set.update({"id": 6})

# %%
set = {"id":5, "name":"john", "department":"Devops"}
set.update({"id":7})
set
# Out:
# {'id': 7, 'name': 'john', 'department': 'Devops'}

# %% [markdown]
# 14. Create two dictionaries and combine them using update().

# %%
set = {"id":5, "name":"john", "department":"Devops"}
stt1 = {"model": 123, "Company":"abc", "Price":20000}
set.update(stt1)
set
# Out:
# {'id': 5,
#  'name': 'john',
#  'department': 'Devops',
#  'model': 123,
#  'Company': 'abc',
#  'Price': 20000}

# %% [markdown]
# 15. Make a dictionary and get the value of a key using get().

# %%
info = {"name":"Robb", "age":24, "city":"Texas"}
info.get("name")
# Out:
# 'Robb'

# %% [markdown]
# 16. Create a dictionary and print its type using type().

# %%
input = {"id":5, "name":"john", "department":"Devops"}
type(input)
# Out:
# dict

# %%
info = {"name":"Robb", "age":24, "city":"Texas"}

info["country"] = "USA"

info
# Out:
# {'name': 'Robb', 'age': 24, 'city': 'Texas', 'country': 'USA'}

# %% [markdown]
# 17. Create a dictionary and replace one value with a new one.

# %%
survy = {"Name":"john", "Number":"1233456789"}

survy["Number"] = "84463675689"
survy
# Out:
# {'Name': 'john', 'Number': '84463675689'}

# %% [markdown]
# 18. Create a dictionary and clear all items using clear().

# %%
input = {"id":5, "name":"john", "department":"Devops"}

input.clear()
input
# Out:
# {}

# %% [markdown]
# 19. Create a dictionary with numbers as keys and names as values. Print the dictionary.

# %%
dic = {1:"names", 2:"city"}
dic
# Out:
# {1: 'names', 2: 'city'}

# %% [markdown]
# 20. Create a dictionary and copy it into a new dictionary using copy().

# %%
details = {"model": 123, "Company":"abc", "Price":20000}
details2 = details.copy()
details2
# Out:
# {'model': 123, 'Company': 'abc', 'Price': 20000}
